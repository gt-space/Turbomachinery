# %%
from Optimizer import run_epump
mdot = 4.84
MR = 2.2


print('================LOx Results================')
results = run_epump(
    prop="lox",
    deltaP=295,
    mdot=mdot,
    MR=MR,
    p_in=140
)
# Out:
# ================LOx Results================
#
# Pump Sizing Results
# ---------------------------------------------
# RPM                           :    1.674e+04
# flow rate (m^3/s)             :     0.003229
# DeltaT (K)                    :            1
# Head (m)                      :        180.5
# Specific Speed                :        19.31
# Reynold's number              :    6.189e+07
#
# Pump Power Results
# ---------------------------------------------
# Power Draw (W)                :    1.143e+04
# Gulich's power(W)             :    1.235e+04
# Available Power (W)           :    1.339e+04
# hydraulic Power (W)           :         8434
# Hydraulic Efficiency          :       0.7787
# Mechanical Parasitic Power (W):         1749
# Disk Friction Losses (W)      :         1245

# %%
print('================RP1 Results================')
results = run_epump(
    prop="rp1",
    deltaP=395,
    mdot=mdot,
    MR=MR,
    p_in=140
)
# Out:
# ================RP1 Results================
#
# Pump Sizing Results
# ---------------------------------------------
# RPM                           :      2.3e+04
# flow rate (m^3/s)             :     0.002016
# DeltaT (K)                    :            5
# Head (m)                      :          345
# Specific Speed                :         12.9
# Reynold's number              :    8.296e+06
#
# Pump Power Results
# ---------------------------------------------
# Power Draw (W)                :    1.411e+04
# Gulich's power(W)             :    1.646e+04
# Available Power (W)           :     1.84e+04
# hydraulic Power (W)           :         8139
# Hydraulic Efficiency          :       0.6748
# Mechanical Parasitic Power (W):         3249
# Disk Friction Losses (W)      :         2727
