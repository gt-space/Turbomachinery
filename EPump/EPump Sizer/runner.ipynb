# %%
from Optimizer import run_epump
mdot = 4.84
MR = 2.2


print('================LOx Results================')
results = run_epump(
    prop="lox",
    deltaP=295,
    mdot=mdot,
    MR=MR,
    p_in=135
)
# Out:
# ================LOx Results================
#
# Pump Sizing Results
# ---------------------------------------------
# RPM                           :    1.676e+04
# flow rate (m^3/s)             :      0.00323
# DeltaT (K)                    :            1
# Head (m)                      :        180.6
# Specific Speed                :        19.34
# Reynold's number              :     6.18e+07
#
# Pump Power Results
# ---------------------------------------------
# Power Draw (W)                :    1.141e+04
# Gulich's power(W)             :    1.234e+04
# Available Power (W)           :    1.341e+04
# hydraulic Power (W)           :         8435
# Hydraulic Efficiency          :       0.7789
# Mechanical Parasitic Power (W):         1730
# Disk Friction Losses (W)      :         1242

# %%
print('================RP1 Results================')
results = run_epump(
    prop="rp1",
    deltaP=425,
    mdot=mdot,
    MR=MR,
    p_in=135
)
# Out:
# ================RP1 Results================
#
# Pump Sizing Results
# ---------------------------------------------
# RPM                           :      2.3e+04
# flow rate (m^3/s)             :      0.00202
# DeltaT (K)                    :            5
# Head (m)                      :        371.2
# Specific Speed                :        12.22
# Reynold's number              :    9.068e+06
#
# Pump Power Results
# ---------------------------------------------
# Power Draw (W)                :    1.559e+04
# Gulich's power(W)             :    1.853e+04
# Available Power (W)           :     1.84e+04
# hydraulic Power (W)           :         8910
# Hydraulic Efficiency          :       0.6642
# Mechanical Parasitic Power (W):         3429
# Disk Friction Losses (W)      :         3256
